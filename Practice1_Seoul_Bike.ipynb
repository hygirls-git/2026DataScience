# %% [markdown]
# <a href="https://colab.research.google.com/github/hygirls-git/2026DataScience/blob/main/Practice1_Seoul_Bike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #서울시 공공자전거 따릉이 대여소 정보
# https://data.seoul.go.kr/dataList/OA-21235/S/1/datasetView.do

# %% [markdown]
# #csv파일 읽기

# %% [markdown]
# #우리 지역구만 출력하기

# %% [markdown]
# #폴리움으로 서울시 지도 그리기(서울시청 중심)

# %% [markdown]
# #우리 지역구 따릉이 대여소 지도에 시각화 하기
